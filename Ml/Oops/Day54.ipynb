# %%
class Animal:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def bark(self):
        return f"{self.name} says woof"
        

dog1=Animal("Buddy",10)
print(dog1)
print(dog1.bark())
# Out:
# ...
# Buddy says woof

# %%
#
